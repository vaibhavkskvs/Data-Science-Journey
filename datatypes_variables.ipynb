# %% [markdown]
# ## Hello World

# %%
print("Hello world!")
# Out:
# Hello world!

# %%
"Hello world!"
#It work without print function only in jupyter notebook not in every python IDE.
# Out:
# 'Hello world!'

# %%
'Hello world'
# Out:
# 'Hello world'

# %% [markdown]
# ### Data Types

# %%
print("Vaibhav Shahi")
# Out:
# Vaibhav Shahi

# %%
print(18)
#just testing what happens if we remove inverted commas from the print function
#it is not necessary to write print function in jupyter notebook
# Out:
# 18

# %%
4-1
# Out:
# 3

# %%
type("Hello world")
# Out:
# str

# %%
"Hello world".upper()
# Out:
# 'HELLO WORLD'

# %%
print("Hello world".upper())
print("Hello world".lower())
print("Hello world".title())
# Out:
# HELLO WORLD
# hello world
# Hello World

# %%
print("Hello world".count('l'))
# Out:
# 3

# %%
print("Hello world".replace('o', 'u'))
# Out:
# Hellu wurld

# %% [markdown]
# ## Variables

# %%
message_1 = "I'm learning poython"

# %%
message_1
# Out:
# "I'm learning poython"

# %%
message_2 = "and it's fun!"

# %%
message_2
# Out:
# 'I am enjoying it'

# %%
'I am learning python'
# Out:
# 'I am learning python'

# %%
#String concatenation
message_1 + ' ' + message_2
# Out:
# "I'm learning poython and it's fun!"

# %%
message = message_1 + ' ' + message_2

# %%
message
# Out:
# "I'm learning poython and it's fun!"

# %%
f'hello world'
# Out:
# 'hello world'

# %%
f'{message_1}'
# Out:
# "I'm learning poython"

# %%
f'{message_1} {message_2}'
# Out:
# "I'm learning poython and it's fun!"

# %%
f'{message_1} ds {message_2}'
# Out:
# "I'm learning poython ds and it's fun!"
