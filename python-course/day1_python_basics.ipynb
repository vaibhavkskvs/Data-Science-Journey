# %% [markdown]
# # 1. Title

# %% [markdown]
# ### 1.1 Subtitle

# %%
"Hello World"
# Out:
# 'Hello World'

# %%
"ctrl + f - Find"
"m - Covert to markdown"
"y - COnvert to code"
"Numbers and # symbols to change the size of the text"
"a - Cell above"
"b - Cell below"
"x - To cut the cell"
"v - To place the cell below"
"shift + v - To place the cell above" #Not working
"Press d twice to delete"
"Press z to undo delete"
