# %% [markdown]
# # List

# %% [markdown]
# Used to store multiple items in a single variable

# %% [markdown]
# Ordered and Mutable

# %%
#By indexing, we can obtain an element by its position.
#Zero based indexing i.e. 15 is at position zero and India is at 1
#Negative indexing i.e reverse order of indexing
#Slicing - Accessing part of the lsit

# %%
Countries = ['India','USA', 'Russia']

# %%
Countries
# Out:
# ['India', 'USA', 'Russia']

# %%
X = ['15', 'India', 'Cricket', '15']

# %%
X
# Out:
# ['15', 'India', 'Cricket', '15']

# %%
print(Countries[0])
print(Countries[1])
print(Countries[2])
# Out:
# India
# USA
# Russia

# %%
Countries[-1]
# Out:
# 'Russia'

# %%
#slicing
#list_name[start:stop]

# %%
Countries[0:2]
#It stops at 2 without including 2.
# Out:
# ['India', 'USA']

# %%
Countries[1:3]
# Out:
# ['USA', 'Russia']

# %% [markdown]
# ### Adding element to a list

# %%
#Append  -  Adds a new element at the last position
#Insert  -  Adds a new element at a specific position

# %%
Countries.append('Canada')

# %%
Countries
# Out:
# ['India', 'USA', 'Russia', 'Canada']

# %%
Countries.insert(1, 'Spain')

# %%
Countries
# Out:
# ['India', 'Spain', 'USA', 'Russia', 'Canada']

# %%
Countries_2 = ['England', 'Germany', 'France']

# %%
Countries_2
# Out:
# ['England', 'Germany', 'France']

# %%
#Concatenate list
Countries + Countries_2
# Out:
# ['India', 'Spain', 'USA', 'Russia', 'Canada', 'England', 'Germany', 'France']

# %%
#Nested list
nested_list = [Countries, Countries_2]

# %%
nested_list
# Out:
# [['India', 'Spain', 'USA', 'Russia', 'Canada'],
#  ['England', 'Germany', 'France']]

# %% [markdown]
# ### Removing an element

# %%
Countries.remove('USA')

# %%
Countries
# Out:
# ['India', 'Spain', 'Russia', 'Canada']

# %%
#pop
Countries.pop(-1)
# Out:
# 'Canada'

# %%
Countries
# Out:
# ['India', 'Spain', 'Russia']

# %% [markdown]
# ### Sorting a list

# %%
numbers = [4, 3, 7, 10, 1, 2]

# %%
numbers.sort()

# %%
numbers
# Out:
# [1, 2, 3, 4, 7, 10]

# %%
numbers = [4, 3, 7, 10, 1, 2]
numbers.sort(reverse=True)
numbers
# Out:
# [10, 7, 4, 3, 2, 1]

# %% [markdown]
# ### Update an element

# %%
numbers[0] = 1000
numbers
# Out:
# [1000, 7, 4, 3, 2, 1]

# %% [markdown]
# ### Copying list

# %%
Countries[:]
# By using only columns: no start or stop commands then it will give the complete list
# Out:
# ['India', 'Spain', 'Russia']

# %%
Countries.copy()
# Out:
# ['India', 'Spain', 'Russia']
