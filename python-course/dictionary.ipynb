# %% [markdown]
# ## Dictionary

# %%
my_dict = {'key1':'value1', 'key2':'value2'}

# %%
my_data = {'name':'Vaibhav', 'age':18}

# %%
my_data
# Out:
# {'name': 'Vaibhav', 'age': 18}

# %%
my_data.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
my_data.values()
# Out:
# dict_values(['Vaibhav', 18])

# %%
my_data.items()
# Out:
# dict_items([('name', 'Vaibhav'), ('age', 18)])

# %%
my_data['height'] = 1.7

# %%
my_data
# Out:
# {'name': 'Vaibhav', 'age': 18, 'height': 1.7}

# %%
my_data.update({'height':1.9})

# %%
my_data
# Out:
# {'name': 'Vaibhav', 'age': 18, 'height': 1.9}

# %% [markdown]
# #### Copy a dictionary

# %%
new_dict = my_data.copy()

# %%
new_dict
# Out:
# {'name': 'Vaibhav', 'age': 18, 'height': 1.8}

# %%
new_dict_2 = my_data

# %%
new_dict_2
# Out:
# {'name': 'Vaibhav', 'age': 18, 'height': 1.9}

# %% [markdown]
# ### Remove element

# %%
my_data.pop('name')
# Out:
# 'Vaibhav'

# %%
my_data
# Out:
# {'age': 18, 'height': 1.9}

# %%
del my_data['height']

# %%
my_data
# Out:
# {'age': 18}

# %%
my_data.clear()
#clear removes all the items which are present in the dictionary

# %%
my_data
# Out:
# {}
